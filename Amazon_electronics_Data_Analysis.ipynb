# %% [markdown]
# Task 1 — Load & Inspect the Dataset
# Load the dataset into your notebook.
# Display first and last 5 rows.
# Print .shape and .info().
# Show list of unique product categories.
# Identify columns that require cleaning or type conversion.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("amazon_products_dataset.csv")

# %%
print("First 5 rows:\n",df.head(5))
print("Last 5 rows:\n",df.tail(5))
# Out:
# First 5 rows:
#                       title    brand    category  actual_price  discount_price  \
# 0      Smart Fitness Watch     Dell      Laptop       69890.0         65271.0
# 1  Laptop with SSD Storage       LG  Smartwatch       66771.0         63977.0
# 2  High Resolution Monitor       Mi  Headphones       43598.0         39679.0
# 3         4K Action Camera       HP      Camera       63408.0         58877.0
# 4      Smart Fitness Watch  Samsung     Monitor       49224.0         45017.0
#
#    rating  rating_count
# 0     2.6        2128.0
# 1     2.5        9118.0
# 2     1.9        2517.0
# 3     3.7       17533.0
# 4     4.9       14228.0
# Last 5 rows:
#                                 title    brand    category  actual_price  \
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 1995         20202.0     3.0       16058.0
# 1996         64559.0     1.1        6655.0
# 1997         18654.0     3.7        5308.0
# 1998         31061.0     2.2       19105.0
# 1999         31047.0     3.2        1064.0

# %%
print("Shape:",df.shape)
print("Info:",df.info())
# Out:
# Shape: (2000, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2000 non-null   object
#  1   brand           2000 non-null   object
#  2   category        1998 non-null   object
#  3   actual_price    1998 non-null   float64
#  4   discount_price  1999 non-null   float64
#  5   rating          1996 non-null   float64
#  6   rating_count    1996 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 109.5+ KB
# Info: None

# %%
print("Unique Product Categories:\n",df['category'].nunique)
# Out:
# Unique Product Categories:
#  <bound method IndexOpsMixin.nunique of 0           Laptop
# 1       Smartwatch
# 2       Headphones
# 3           Camera
# 4          Monitor
#            ...
# 1995       Monitor
# 1996    Headphones
# 1997    Smartphone
# 1998    Smartwatch
# 1999    Headphones
# Name: category, Length: 2000, dtype: object>

# %% [markdown]
# Task 2 — Clean the Dataset
# Identify missing values using .isnull().sum().
# Fill missing numeric values (discount_price, rating, etc.) using mean or median.
# Fill missing categorical values (brand, category) with "Unknown".
# Remove all duplicate rows.
# Convert numeric columns to their correct data types.
# Reset index after cleaning.

# %%
df.isnull().sum()
# Out:
# title             0
# brand             0
# category          2
# actual_price      2
# discount_price    1
# rating            4
# rating_count      4
# dtype: int64

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 0            65271.0     2.6        2128.0
# 1            63977.0     2.5        9118.0
# 2            39679.0     1.9        2517.0
# 3            58877.0     3.7       17533.0
# 4            45017.0     4.9       14228.0
# ...              ...     ...           ...
# 1995         20202.0     3.0       16058.0
# 1996         64559.0     1.1        6655.0
# 1997         18654.0     3.7        5308.0
# 1998         31061.0     2.2       19105.0
# 1999         31047.0     3.2        1064.0
#
# [2000 rows x 7 columns]

# %%
df['discount_price'].fillna(df.discount_price.mean(),inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14136\1520284807.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['discount_price'].fillna(df.discount_price.mean(),inplace=True)

# %%
df['rating'].fillna(df.rating.mean(),inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14136\2108311624.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(df.rating.mean(),inplace=True)

# %%
df['category'].fillna("Unknown",inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14136\119376163.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['category'].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# title             0
# brand             0
# category          0
# actual_price      2
# discount_price    0
# rating            0
# rating_count      4
# dtype: int64

# %%
df['actual_price'].fillna(df.actual_price.mean(),inplace=True)
df['rating_count'].fillna(df.rating_count.mean(),inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14136\648253791.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['actual_price'].fillna(df.actual_price.mean(),inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14136\648253791.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating_count'].fillna(df.rating_count.mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# title             0
# brand             0
# category          0
# actual_price      0
# discount_price    0
# rating            0
# rating_count      0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2000 non-null   object
#  1   brand           2000 non-null   object
#  2   category        2000 non-null   object
#  3   actual_price    2000 non-null   float64
#  4   discount_price  2000 non-null   float64
#  5   rating          2000 non-null   float64
#  6   rating_count    2000 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 109.5+ KB

# %%
df.reset_index(drop=True,inplace=True)
df.head(5)
# Out:
#                      title    brand    category  actual_price  discount_price  \
# 0      Smart Fitness Watch     Dell      Laptop       69890.0         65271.0
# 1  Laptop with SSD Storage       LG  Smartwatch       66771.0         63977.0
# 2  High Resolution Monitor       Mi  Headphones       43598.0         39679.0
# 3         4K Action Camera       HP      Camera       63408.0         58877.0
# 4      Smart Fitness Watch  Samsung     Monitor       49224.0         45017.0
#
#    rating  rating_count
# 0     2.6        2128.0
# 1     2.5        9118.0
# 2     1.9        2517.0
# 3     3.7       17533.0
# 4     4.9       14228.0

# %% [markdown]
# Task 3 — Data Analysis
# Identify the top 5 most expensive products (actual_price).
# Find the brand with the highest number of products.
# Compute the average discount percentage for each brand.
# Identify products with rating ≥ 4.5 and rating_count ≥ 2000.
# Compute category-wise average price.

# %%
top_pr=df.sort_values(by="actual_price",ascending=False).head(5)
top_pr
# Out:
#                  title  brand    category  actual_price  discount_price  \
# 1383    Android Tablet    JBL      Laptop       79993.0         78094.0
# 1974     Gaming Laptop     LG     Monitor       79869.0         77173.0
# 1403  4K Action Camera   Sony  Headphones       79857.0         77469.0
# 1351    Android Tablet   Sony     Monitor       79853.0         78831.0
# 42       Gaming Laptop  Apple  Smartwatch       79826.0         76919.0
#
#       rating  rating_count
# 1383     3.0        7666.0
# 1974     2.6        5232.0
# 1403     2.7        1379.0
# 1351     4.8        7596.0
# 42       3.8       10252.0

# %%
df['brand'].value_counts().head(1)
# Out:
# brand
# Boat    214
# Name: count, dtype: int64

# %%
df['discount_percentage']=(df['discount_price']/df['actual_price'])*100
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count  discount_percentage
# 0            65271.0     2.6        2128.0            93.391043
# 1            63977.0     2.5        9118.0            95.815549
# 2            39679.0     1.9        2517.0            91.011056
# 3            58877.0     3.7       17533.0            92.854214
# 4            45017.0     4.9       14228.0            91.453356
# ...              ...     ...           ...                  ...
# 1995         20202.0     3.0       16058.0            83.686827
# 1996         64559.0     1.1        6655.0            98.640163
# 1997         18654.0     3.7        5308.0            87.339639
# 1998         31061.0     2.2       19105.0            88.168838
# 1999         31047.0     3.2        1064.0            98.057608
#
# [2000 rows x 8 columns]

# %%
df.groupby('brand')['discount_percentage'].mean()
# Out:
# brand
# Apple      87.278004
# Boat       87.453498
# Dell       88.834996
# HP         88.498798
# JBL        88.629863
# LG         88.031201
# Mi         89.837692
# OnePlus    88.619013
# Samsung    90.697427
# Sony       89.611127
# Name: discount_percentage, dtype: float64

# %%
df[(df['rating']>=4.5) & (df['rating_count']>=2000)]
# Out:
#                                title    brand    category  actual_price  \
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# 32                  4K Action Camera  OnePlus  Smartphone        7793.0
# 51     Wireless Bluetooth Headphones     Dell  Headphones       61569.0
# 52           Laptop with SSD Storage     Boat  Smartwatch       76286.0
# 59                     Gaming Laptop  Samsung      Tablet       45250.0
# ...                              ...      ...         ...           ...
# 1949      Portable Bluetooth Speaker  OnePlus      Tablet       59325.0
# 1970                  Android Tablet     Boat      Camera       20841.0
# 1975   Wireless Bluetooth Headphones  Samsung  Smartwatch       31973.0
# 1982   Wireless Bluetooth Headphones       HP      Camera       15343.0
# 1988  Smartphone with AMOLED Display       LG      Tablet       29783.0
#
#       discount_price  rating  rating_count  discount_percentage
# 4            45017.0     4.9       14228.0            91.453356
# 32            5953.0     4.6        5066.0            76.389067
# 51           59372.0     4.5       13402.0            96.431646
# 52           75621.0     5.0        7433.0            99.128280
# 59           44710.0     4.7        4643.0            98.806630
# ...              ...     ...           ...                  ...
# 1949         55777.0     4.5       19070.0            94.019385
# 1970         17765.0     4.5       10252.0            85.240631
# 1975         27058.0     4.5        4288.0            84.627655
# 1982         10814.0     4.5        7851.0            70.481653
# 1988         25591.0     5.0       13709.0            85.924856
#
# [218 rows x 8 columns]

# %%
df.groupby('category')['actual_price'].mean()
# Out:
# category
# Camera        40352.246094
# Headphones    39576.147679
# Laptop        40822.874477
# Monitor       39949.431596
# Smartphone    37909.529412
# Smartwatch    38316.913934
# Speaker       39683.449141
# Tablet        39943.815217
# Unknown       33610.500000
# Name: actual_price, dtype: float64

# %% [markdown]
# Task 4 — Programming Task: Feature Engineering + Logical Filters
# Task 4A — Create New Columns
# Write code to create:
# discount_percent = ((actual_price - discount_price) / actual_price) * 100
# price_category based on:
# actual_price < 500 → "Budget"
# 500 ≤ price < 2000 → "Midrange"
# price ≥ 2000 → "Premium"
# popularity_score = rating * log(rating_count + 1)

# %% [markdown]
# Task 4B — Filtering Using New Columns
# Using the newly created columns:
# Show top 10 highest popularity_score products.
# Show all Premium category items with discount_percent > 40%.
# Show all products whose title contains "Bluetooth" (string filter).
# Show products where:
# rating >= 4.0
# discount_percent between 20% to 50%
# popularity_score in the top 30% percentile
# (Use .between() and .quantile())

# %% [markdown]
# Task 4C — Grouping with New Columns
# Find the average discount_percent for each brand.
# Find the average popularity_score for each price_category.
# Identify which category offers the highest average discount.
# Calculate total revenue potential per brand using:
# revenue_potential = actual_price * rating_count

# %%
df['price_category']=pd.cut(df['actual_price'],bins=[0,500,2000,np.inf],labels=['Budget','Midrange','Premium'])

# %%
df['popularity_score']=df['rating']*np.log10(df['rating_count']+1)

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count  discount_percentage  \
# 0            65271.0     2.6        2128.0            93.391043
# 1            63977.0     2.5        9118.0            95.815549
# 2            39679.0     1.9        2517.0            91.011056
# 3            58877.0     3.7       17533.0            92.854214
# 4            45017.0     4.9       14228.0            91.453356
# ...              ...     ...           ...                  ...
# 1995         20202.0     3.0       16058.0            83.686827
# 1996         64559.0     1.1        6655.0            98.640163
# 1997         18654.0     3.7        5308.0            87.339639
# 1998         31061.0     2.2       19105.0            88.168838
# 1999         31047.0     3.2        1064.0            98.057608
#
#      price_category  popularity_score
# 0           Premium          8.653257
# 1           Premium          9.899868
# 2           Premium          6.462006
# 3           Premium         15.702360
# 4           Premium         20.350554
# ...             ...               ...
# 1995        Premium         12.617155
# 1996        Premium          4.205535
# 1997        Premium         13.782547
# 1998        Premium          9.418574
# 1999        Premium          9.687519
#
# [2000 rows x 10 columns]

# %%
top10_hp=df.sort_values(by="popularity_score",ascending=False).head(10)
top10_hp
# Out:
#                                title    brand    category  actual_price  \
# 1418  Smartphone with AMOLED Display  OnePlus      Laptop       22786.0
# 297       Portable Bluetooth Speaker  Samsung      Camera       52713.0
# 502    Wireless Bluetooth Headphones  Samsung      Camera       17858.0
# 1400         High Resolution Monitor     Dell  Headphones       11025.0
# 878          Laptop with SSD Storage    Apple  Smartwatch        4436.0
# 1489         High Resolution Monitor    Apple      Laptop       21711.0
# 848          High Resolution Monitor       HP  Smartphone       11660.0
# 854       Portable Bluetooth Speaker  Samsung  Smartwatch       19284.0
# 1625                   Gaming Laptop     Dell      Tablet       15099.0
# 637                 4K Action Camera     Dell  Headphones       35058.0
#
#       discount_price  rating  rating_count  discount_percentage  \
# 1418         22301.0     5.0       18510.0            97.871500
# 297          48399.0     5.0       17776.0            91.816061
# 502          14713.0     5.0       16732.0            82.388845
# 1400          8407.0     5.0       15958.0            76.253968
# 878           2614.0     4.9       18895.0            58.926961
# 1489         20325.0     4.9       18862.0            93.616139
# 848           9248.0     4.9       18547.0            79.313894
# 854          14650.0     4.9       18109.0            75.969716
# 1625         12224.0     5.0       14322.0            80.959004
# 637          33177.0     4.9       17254.0            94.634606
#
#      price_category  popularity_score
# 1418        Premium         21.337149
# 297         Premium         21.249292
# 502         Premium         21.117869
# 1400        Premium         21.015028
# 878         Premium         20.954212
# 1489        Premium         20.950493
# 848         Premium         20.914656
# 854         Premium         20.863800
# 1625        Premium         20.780170
# 637         Premium         20.760883

# %%
df[(df['price_category']=='Premium') & (df['discount_percentage']>30)]
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count  discount_percentage  \
# 0            65271.0     2.6        2128.0            93.391043
# 1            63977.0     2.5        9118.0            95.815549
# 2            39679.0     1.9        2517.0            91.011056
# 3            58877.0     3.7       17533.0            92.854214
# 4            45017.0     4.9       14228.0            91.453356
# ...              ...     ...           ...                  ...
# 1995         20202.0     3.0       16058.0            83.686827
# 1996         64559.0     1.1        6655.0            98.640163
# 1997         18654.0     3.7        5308.0            87.339639
# 1998         31061.0     2.2       19105.0            88.168838
# 1999         31047.0     3.2        1064.0            98.057608
#
#      price_category  popularity_score
# 0           Premium          8.653257
# 1           Premium          9.899868
# 2           Premium          6.462006
# 3           Premium         15.702360
# 4           Premium         20.350554
# ...             ...               ...
# 1995        Premium         12.617155
# 1996        Premium          4.205535
# 1997        Premium         13.782547
# 1998        Premium          9.418574
# 1999        Premium          9.687519
#
# [1930 rows x 10 columns]

# %%
df[df['title'].str.contains("Bluetooth")]
# Out:
#                               title    brand    category  actual_price  \
# 14       Portable Bluetooth Speaker  OnePlus      Camera       25516.0
# 18       Portable Bluetooth Speaker     Sony     Monitor       73590.0
# 21    Wireless Bluetooth Headphones  Samsung     Speaker       78689.0
# 23       Portable Bluetooth Speaker       HP  Smartwatch        4342.0
# 25    Wireless Bluetooth Headphones     Boat     Monitor       14689.0
# ...                             ...      ...         ...           ...
# 1975  Wireless Bluetooth Headphones  Samsung  Smartwatch       31973.0
# 1979  Wireless Bluetooth Headphones     Sony     Monitor       65124.0
# 1982  Wireless Bluetooth Headphones       HP      Camera       15343.0
# 1985  Wireless Bluetooth Headphones       Mi  Smartwatch       50527.0
# 1986     Portable Bluetooth Speaker  Samsung     Monitor       53328.0
#
#       discount_price  rating  rating_count  discount_percentage  \
# 14           24050.0     1.7       16989.0            94.254585
# 18           69414.0     3.8        9759.0            94.325316
# 21           76240.0     2.9       10196.0            96.887748
# 23            4235.0     1.4        4820.0            97.535698
# 25           13286.0     3.7        1849.0            90.448635
# ...              ...     ...           ...                  ...
# 1975         27058.0     4.5        4288.0            84.627655
# 1979         61923.0     3.3       16581.0            95.084761
# 1982         10814.0     4.5        7851.0            70.481653
# 1985         45694.0     2.8        3692.0            90.434817
# 1986         52129.0     3.2       19467.0            97.751650
#
#      price_category  popularity_score
# 14          Premium          7.191329
# 18          Premium         15.159909
# 21          Premium         11.624570
# 23          Premium          5.156392
# 25          Premium         12.088535
# ...             ...               ...
# 1975        Premium         16.345602
# 1979        Premium         13.924802
# 1982        Premium         17.527411
# 1985        Premium          9.988662
# 1986        Premium         13.725828
#
# [415 rows x 10 columns]

# %%
df[(df['rating']>=4.0) & (df['discount_percentage'].between(20,50)) & (df['popularity_score']>df['popularity_score'].quantile(0.70))]
# Out:
#                               title    brand    category  actual_price  \
# 145   Wireless Bluetooth Headphones      JBL      Laptop        9421.0
# 375         High Resolution Monitor       HP     Speaker        5058.0
# 618                4K Action Camera     Dell  Smartphone        9565.0
# 698        Noise Cancelling Earbuds       LG      Camera        5197.0
# 964   Wireless Bluetooth Headphones     Dell  Headphones        4882.0
# 1208                 Android Tablet  OnePlus  Smartwatch         954.0
# 1481       Noise Cancelling Earbuds  Samsung  Headphones        7494.0
# 1720        Laptop with SSD Storage  Samsung     Speaker        1511.0
# 1793        High Resolution Monitor       Mi  Headphones        3620.0
#
#       discount_price  rating  rating_count  discount_percentage  \
# 145           4473.0     4.3       12443.0            47.479036
# 375           2343.0     4.6       19129.0            46.322657
# 618           4656.0     4.4       11218.0            48.677470
# 698           2526.0     5.0        9638.0            48.604964
# 964           1916.0     4.2       17932.0            39.246211
# 1208           464.0     4.6       17175.0            48.637317
# 1481          3421.0     4.2       15059.0            45.649853
# 1720           362.0     4.6        9438.0            23.957644
# 1793          1463.0     4.0       17890.0            40.414365
#
#      price_category  popularity_score
# 145         Premium         17.608328
# 375         Premium         19.695889
# 618         Premium         17.819798
# 698         Premium         19.920160
# 964         Premium         17.865342
# 1208       Midrange         19.480641
# 1481        Premium         17.546865
# 1720       Midrange         18.284660
# 1793        Premium         17.010538

# %%
df.groupby('brand')['discount_percentage'].mean()
# Out:
# brand
# Apple      87.278004
# Boat       87.453498
# Dell       88.834996
# HP         88.498798
# JBL        88.629863
# LG         88.031201
# Mi         89.837692
# OnePlus    88.619013
# Samsung    90.697427
# Sony       89.611127
# Name: discount_percentage, dtype: float64

# %%
df.groupby('price_category')['popularity_score'].mean()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14136\3378229776.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('price_category')['popularity_score'].mean()
# price_category
# Budget      16.567127
# Midrange    10.275548
# Premium     11.451005
# Name: popularity_score, dtype: float64

# %%
df.groupby('category')['discount_percentage'].mean()
# Out:
# category
# Camera        89.380530
# Headphones    87.397234
# Laptop        88.792445
# Monitor       89.923398
# Smartphone    88.483550
# Smartwatch    87.971265
# Speaker       89.120790
# Tablet        88.633299
# Unknown       88.279148
# Name: discount_percentage, dtype: float64

# %%
df['revenue_potential']=df['actual_price']*df['rating_count']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Task 5 — Data Visualization
# Use the specific plot type mentioned:
# Price distribution → Histogram + KDE
# Relationship between price and rating → Scatter Plot
# Category-wise average rating → Bar Plot
# Brand product count → Count Plot
# Numeric feature correlations → Heatmap

# %%
sns.histplot(df['actual_price'],bins=40,kde=True)
# Out:
# <Axes: xlabel='actual_price', ylabel='Count'>

# %%
sns.scatterplot(x=df['actual_price'], y=df['rating'])
# Out:
# <Axes: xlabel='actual_price', ylabel='rating'>

# %%
plt.bar(df.groupby('category')['rating'].mean().index,df.groupby("category")['rating'].mean().values)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Camera'),
#   Text(1, 0, 'Headphones'),
#   Text(2, 0, 'Laptop'),
#   Text(3, 0, 'Monitor'),
#   Text(4, 0, 'Smartphone'),
#   Text(5, 0, 'Smartwatch'),
#   Text(6, 0, 'Speaker'),
#   Text(7, 0, 'Tablet'),
#   Text(8, 0, 'Unknown')])

# %%
sns.countplot(df['brand'])
# Out:
# <Axes: xlabel='count', ylabel='brand'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                2000 non-null   object
#  1   brand                2000 non-null   object
#  2   category             2000 non-null   object
#  3   actual_price         2000 non-null   float64
#  4   discount_price       2000 non-null   float64
#  5   rating               2000 non-null   float64
#  6   rating_count         2000 non-null   float64
#  7   discount_percentage  2000 non-null   float64
#  8   price_category       2000 non-null   category
#  9   popularity_score     2000 non-null   float64
#  10  revenue_potential    2000 non-null   float64
# dtypes: category(1), float64(7), object(3)
# memory usage: 158.5+ KB

# %%
sns.heatmap(df[['actual_price','discount_price','rating','rating_count']])
# Out:
# <Axes: >

# %%
df.to_csv("amazon_products_cleaned_dataset.csv")

# %%
pd.read_csv("amazon_products_cleaned_dataset.csv").head()
# Out:
#    Unnamed: 0                    title    brand    category  actual_price  \
# 0           0      Smart Fitness Watch     Dell      Laptop       69890.0
# 1           1  Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2           2  High Resolution Monitor       Mi  Headphones       43598.0
# 3           3         4K Action Camera       HP      Camera       63408.0
# 4           4      Smart Fitness Watch  Samsung     Monitor       49224.0
#
#    discount_price  rating  rating_count  discount_percentage price_category  \
# 0         65271.0     2.6        2128.0            93.391043        Premium
# 1         63977.0     2.5        9118.0            95.815549        Premium
# 2         39679.0     1.9        2517.0            91.011056        Premium
# 3         58877.0     3.7       17533.0            92.854214        Premium
# 4         45017.0     4.9       14228.0            91.453356        Premium
#
#    popularity_score  revenue_potential
# 0          8.653257       1.487259e+08
# 1          9.899868       6.088180e+08
# 2          6.462006       1.097362e+08
# 3         15.702360       1.111732e+09
# 4         20.350554       7.003591e+08
